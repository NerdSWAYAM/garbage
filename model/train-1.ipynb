# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
import torch

pipe = pipeline("image-classification", model="watersplash/waste-classification")
# Out:
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
pipe("waste.png")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/transformers/image_utils.py:465, in load_image(image, timeout)
#     464     b64 = base64.decodebytes(image.encode())
# --> 465     image = PIL.Image.open(BytesIO(b64))
#     466 except Exception as e:
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/PIL/Image.py:3579, in open(fp, mode, formats)
#    3578 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3579 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7e57d274a8e0>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pipe("waste.png")
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:181, in ImageClassificationPipeline.__call__(self, inputs, **kwargs)
#     179 if inputs is None:
#     180     raise ValueError("Cannot call the image-classification pipeline without an inputs argument!")
# --> 181 return super().__call__(inputs, **kwargs)
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/transformers/pipelines/base.py:1267, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1259     return next(
#    1260         iter(
#    1261             self.get_iterator(
#    (...)   1264         )
#    1265     )
#    1266 else:
# -> 1267     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/transformers/pipelines/base.py:1273, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1272 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
# -> 1273     model_inputs = self.preprocess(inputs, **preprocess_params)
#    1274     model_outputs = self.forward(model_inputs, **forward_params)
#    1275     outputs = self.postprocess(model_outputs, **postprocess_params)
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:184, in ImageClassificationPipeline.preprocess(self, image, timeout)
#     183 def preprocess(self, image, timeout=None):
# --> 184     image = load_image(image, timeout=timeout)
#     185     model_inputs = self.image_processor(images=image, return_tensors="pt")
#     186     model_inputs = model_inputs.to(self.dtype)
#
# File ~/miniconda3/envs/ML/lib/python3.11/site-packages/transformers/image_utils.py:467, in load_image(image, timeout)
#     465             image = PIL.Image.open(BytesIO(b64))
#     466         except Exception as e:
# --> 467             raise ValueError(
#     468                 f"Incorrect image source. Must be a valid URL starting with `http://` or `https://`, a valid path to an image file, or a base64 encoded string. Got {image}. Failed with {e}"
#     469             )
#     470 elif not isinstance(image, PIL.Image.Image):
#     471     raise TypeError(
#     472         "Incorrect format used for image. Should be an url linking to an image, a base64 string, a local path, or a PIL image."
#     473     )
#
# ValueError: Incorrect image source. Must be a valid URL starting with `http://` or `https://`, a valid path to an image file, or a base64 encoded string. Got waste.png. Failed with cannot identify image file <_io.BytesIO object at 0x7e57d274a8e0>

# %%
pipe("https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/hub/parrots.png")

# %%
# Load model directly
from transformers import AutoImageProcessor, AutoModelForImageClassification

processor = AutoImageProcessor.from_pretrained("watersplash/waste-classification")
model = AutoModelForImageClassification.from_pretrained("watersplash/waste-classification")
